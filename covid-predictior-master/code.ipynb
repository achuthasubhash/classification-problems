# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("E:\\github\\my upload\\covid\\data\\corona_data.csv")

# %%
data.head()
# Out:
#    Age  Fever  BodyPains  RunnyNose  Difficulty_in_Breath  \
# 0   60    100          1          1                     1
# 1   75    102          1          0                     0
# 2   25     98          0          0                     0
# 3   34     97          0          0                     0
# 4    4     96          0          1                     0
#
#    infection_Probability
# 0                      0
# 1                      1
# 2                      1
# 3                      0
# 4                      1

# %%
data.isnull().any()
# Out:
# Age                      False
# Fever                    False
# BodyPains                False
# RunnyNose                False
# Difficulty_in_Breath     False
# infection_Probability    False
# dtype: bool

# %%
data.Age.hist()

# %%
data.Fever.hist()

# %%
data.boxplot(column=['Age', 'Fever'])

# %%
data.infection_Probability.hist()

# %%
sns.pairplot(data, hue="infection_Probability")

# %%
x=data[['Age','Fever','BodyPains','RunnyNose','Difficulty_in_Breath']]

# %%
x
# Out:
#       Age  Fever  BodyPains  RunnyNose  Difficulty_in_Breath
# 0      60    100          1          1                     1
# 1      75    102          1          0                     0
# 2      25     98          0          0                     0
# 3      34     97          0          0                     0
# 4       4     96          0          1                     0
# ...   ...    ...        ...        ...                   ...
# 7099   60    108          1          1                     1
# 7100   22    104          0          0                     0
# 7101    7    102          0          0                     0
# 7102   17     98          0          0                     1
# 7103   90     99          0          0                     1
#
# [7104 rows x 5 columns]

# %%
y=data['infection_Probability']

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(x, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=0, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
filename = 'finalized_model.sav'
pickle.dump(classifier, open(filename, 'wb'))
